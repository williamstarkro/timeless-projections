# %%
# %matplotlib inline
# %reload_ext autoreload
# %autoreload 2

from main import Projection
import matplotlib.pyplot as plt

# %%
inst = Projection(5000000, 3, 'out.csv')
inst.addSections(1, 0, 10)
inst.df.tail()
# Out:
#         Users     Price       Economy        TVTNum   InvestorTVT  \
# 1796  5583989  0.006218  1.361377e+11  2.189253e+13  2.634720e+10
# 1797  5575847  0.006416  1.404556e+11  2.189253e+13  2.608373e+10
# 1798  5612283  0.006388  1.398581e+11  2.189253e+13  2.582289e+10
# 1799  5398773  0.005946  1.301644e+11  2.189253e+13  2.556466e+10
# 1800  5338556  0.007000  1.388025e+11  1.982892e+13  2.530902e+10
#
#       InvestorPerc  InvestorSell  InvestorReturn  InvestorPercReturn  \
# 1796      0.001203  1.572191e+06    5.221887e+09         1043.377482
# 1797      0.001191  1.605836e+06    5.226999e+09         1044.399887
# 1798      0.001180  1.583015e+06    5.226204e+09         1044.240848
# 1799      0.001168  1.458562e+06    5.214693e+09         1041.938699
# 1800      0.001156  1.539802e+06    5.241399e+09         1047.279780
#
#               Bond
# 1796  3.990015e+12
# 1797  3.990015e+12
# 1798  3.990015e+12
# 1799  3.990015e+12
# 1800  6.053619e+12

# %%
for coln in inst.df.columns:
    inst.df[coln].plot(title=coln, figsize=(20,10))
    plt.show()
